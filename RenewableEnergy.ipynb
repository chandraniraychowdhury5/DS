# %% [markdown]
# <a href="https://colab.research.google.com/github/chandraniraychowdhury5/DS/blob/main/RenewableEnergy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv('/content/drive/MyDrive/datasetAndProgram/raw_renewable_energy_dataset.csv')
print(df.head())
print(df.info())
print(df.columns)
# Out:
#      Country  Year Energy Type  Production (GWh)  Installed Capacity (MW)  \
# 0        USA  2011       Solar      85404.690027              5549.794323
# 1  Australia  2008  Geothermal      22205.069382             43211.593798
# 2     Canada  2013     Biomass      94102.732038              6139.117212
# 3      Japan  2010     Biomass      88771.932910             40323.639260
# 4      China  2018       Solar      93288.408581             30755.403056
#
#    Investments (USD)  Population           GDP  Energy Consumption  \
# 0       5.604125e+09  1064007213  1.775278e+14       369654.644184
# 1       6.361886e+08  1033255852  6.435372e+13       771781.636293
# 2       6.158680e+09    14895124  1.567926e+14       342707.152899
# 3       8.526116e+09  1448827283  1.350464e+14       498839.574253
# 4       5.086237e+09  1499494307  8.677956e+13       819064.362785
#
#    Energy Exports  ...  Economic Freedom Index  Ease of Doing Business  \
# 0    93087.198199  ...               49.216800               57.678605
# 1     1752.536054  ...               79.990942                1.761579
# 2    65146.592498  ...               94.374040               77.657334
# 3    50257.591014  ...               65.143472               44.987734
# 4    63101.395562  ...               86.213626               62.535223
#
#    Innovation Index  Number of Research Institutions  \
# 0         76.803228                              851
# 1         48.697825                              590
# 2         67.334813                              101
# 3          4.544289                              327
# 4         10.287199                              985
#
#    Number of Renewable Energy Conferences  \
# 0                                      75
# 1                                      39
# 2                                       7
# 3                                       3
# 4                                      69
#
#    Number of Renewable Energy Publications  Energy Sector Workforce  \
# 0                                     6361                   511658
# 1                                     9752                   974948
# 2                                      311                   326318
# 3                                     7708                   506078
# 4                                     4919                   187964
#
#    Proportion of Energy from Renewables  \
# 0                             25.907895
# 1                             95.003547
# 2                             67.354539
# 3                             33.754104
# 4                             59.509228
#
#    Public-Private Partnerships in Energy  \
# 0                                      1
# 1                                      0
# 2                                      1
# 3                                      0
# 4                                      1
#
#    Regional Renewable Energy Cooperation
# 0                                      0
# 1                                      1
# 2                                      0
# 3                                      0
# 4                                      0
#
# [5 rows x 56 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 56 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Country                                  2500 non-null   object
#  1   Year                                     2500 non-null   int64
#  2   Energy Type                              2500 non-null   object
#  3   Production (GWh)                         2500 non-null   float64
#  4   Installed Capacity (MW)                  2500 non-null   float64
#  5   Investments (USD)                        2500 non-null   float64
#  6   Population                               2500 non-null   int64
#  7   GDP                                      2500 non-null   float64
#  8   Energy Consumption                       2500 non-null   float64
#  9   Energy Exports                           2500 non-null   float64
#  10  Energy Imports                           2500 non-null   float64
#  11  CO2 Emissions                            2500 non-null   float64
#  12  Renewable Energy Jobs                    2500 non-null   int64
#  13  Government Policies                      2500 non-null   int64
#  14  R&D Expenditure                          2500 non-null   float64
#  15  Renewable Energy Targets                 2500 non-null   int64
#  16  Average Annual Temperature               2500 non-null   float64
#  17  Annual Rainfall                          2500 non-null   float64
#  18  Solar Irradiance                         2500 non-null   float64
#  19  Wind Speed                               2500 non-null   float64
#  20  Hydro Potential                          2500 non-null   float64
#  21  Geothermal Potential                     2500 non-null   float64
#  22  Biomass Availability                     2500 non-null   float64
#  23  Energy Storage Capacity                  2500 non-null   float64
#  24  Grid Integration Capability              2500 non-null   float64
#  25  Electricity Prices                       2500 non-null   float64
#  26  Energy Subsidies                         2500 non-null   float64
#  27  International Aid for Renewables         2500 non-null   float64
#  28  Public Awareness                         2500 non-null   float64
#  29  Energy Efficiency Programs               2500 non-null   int64
#  30  Urbanization Rate                        2500 non-null   float64
#  31  Industrialization Rate                   2500 non-null   float64
#  32  Energy Market Liberalization             2500 non-null   int64
#  33  Renewable Energy Patents                 2500 non-null   int64
#  34  Educational Level                        2500 non-null   float64
#  35  Technology Transfer Agreements           2500 non-null   int64
#  36  Renewable Energy Education Programs      2500 non-null   int64
#  37  Local Manufacturing Capacity             2500 non-null   float64
#  38  Import Tariffs on Energy Equipment       2500 non-null   float64
#  39  Export Incentives for Energy Equipment   2500 non-null   float64
#  40  Natural Disasters                        2500 non-null   int64
#  41  Political Stability                      2500 non-null   float64
#  42  Corruption Perception Index              2500 non-null   float64
#  43  Regulatory Quality                       2500 non-null   float64
#  44  Rule of Law                              2500 non-null   float64
#  45  Control of Corruption                    2500 non-null   float64
#  46  Economic Freedom Index                   2500 non-null   float64
#  47  Ease of Doing Business                   2500 non-null   float64
#  48  Innovation Index                         2500 non-null   float64
#  49  Number of Research Institutions          2500 non-null   int64
#  50  Number of Renewable Energy Conferences   2500 non-null   int64
#  51  Number of Renewable Energy Publications  2500 non-null   int64
#  52  Energy Sector Workforce                  2500 non-null   int64
#  53  Proportion of Energy from Renewables     2500 non-null   float64
#  54  Public-Private Partnerships in Energy    2500 non-null   int64
#  55  Regional Renewable Energy Cooperation    2500 non-null   int64
# dtypes: float64(37), int64(17), object(2)
# memory usage: 1.1+ MB
# None
# Index(['Country', 'Year', 'Energy Type', 'Production (GWh)',
#        'Installed Capacity (MW)', 'Investments (USD)', 'Population', 'GDP',
#        'Energy Consumption', 'Energy Exports', 'Energy Imports',
#        'CO2 Emissions', 'Renewable Energy Jobs', 'Government Policies',
#        'R&D Expenditure', 'Renewable Energy Targets',
#        'Average Annual Temperature', 'Annual Rainfall', 'Solar Irradiance',
#        'Wind Speed', 'Hydro Potential', 'Geothermal Potential',
#        'Biomass Availability', 'Energy Storage Capacity',
#        'Grid Integration Capability', 'Electricity Prices', 'Energy Subsidies',
#        'International Aid for Renewables', 'Public Awareness',
#        'Energy Efficiency Programs', 'Urbanization Rate',
#        'Industrialization Rate', 'Energy Market Liberalization',
#        'Renewable Energy Patents', 'Educational Level',
#        'Technology Transfer Agreements', 'Renewable Energy Education Programs',
#        'Local Manufacturing Capacity', 'Import Tariffs on Energy Equipment',
#        'Export Incentives for Energy Equipment', 'Natural Disasters',
#        'Political Stability', 'Corruption Perception Index',
#        'Regulatory Quality', 'Rule of Law', 'Control of Corruption',
#        'Economic Freedom Index', 'Ease of Doing Business', 'Innovation Index',
#        'Number of Research Institutions',
#        'Number of Renewable Energy Conferences',
#        'Number of Renewable Energy Publications', 'Energy Sector Workforce',
#        'Proportion of Energy from Renewables',
#        'Public-Private Partnerships in Energy',
#        'Regional Renewable Energy Cooperation'],
#       dtype='object')

# %% [markdown]
# DATA CLEANING

# %%
#missing values
print(df.isnull().sum())
#filled missing value with mean
df.fillna(df.mean(numeric_only=True), inplace = True)
#duplicates data
print(df.duplicated().sum())
#drop duplicates
df.drop_duplicates(inplace = True)
df.to_csv('/content/drive/MyDrive/datasetAndProgram/clean_renewable_energy_dataset.csv', index = False)
# Out:
# Country                                    0
# Year                                       0
# Energy Type                                0
# Production (GWh)                           0
# Installed Capacity (MW)                    0
# Investments (USD)                          0
# Population                                 0
# GDP                                        0
# Energy Consumption                         0
# Energy Exports                             0
# Energy Imports                             0
# CO2 Emissions                              0
# Renewable Energy Jobs                      0
# Government Policies                        0
# R&D Expenditure                            0
# Renewable Energy Targets                   0
# Average Annual Temperature                 0
# Annual Rainfall                            0
# Solar Irradiance                           0
# Wind Speed                                 0
# Hydro Potential                            0
# Geothermal Potential                       0
# Biomass Availability                       0
# Energy Storage Capacity                    0
# Grid Integration Capability                0
# Electricity Prices                         0
# Energy Subsidies                           0
# International Aid for Renewables           0
# Public Awareness                           0
# Energy Efficiency Programs                 0
# Urbanization Rate                          0
# Industrialization Rate                     0
# Energy Market Liberalization               0
# Renewable Energy Patents                   0
# Educational Level                          0
# Technology Transfer Agreements             0
# Renewable Energy Education Programs        0
# Local Manufacturing Capacity               0
# Import Tariffs on Energy Equipment         0
# Export Incentives for Energy Equipment     0
# Natural Disasters                          0
# Political Stability                        0
# Corruption Perception Index                0
# Regulatory Quality                         0
# Rule of Law                                0
# Control of Corruption                      0
# Economic Freedom Index                     0
# Ease of Doing Business                     0
# Innovation Index                           0
# Number of Research Institutions            0
# Number of Renewable Energy Conferences     0
# Number of Renewable Energy Publications    0
# Energy Sector Workforce                    0
# Proportion of Energy from Renewables       0
# Public-Private Partnerships in Energy      0
# Regional Renewable Energy Cooperation      0
# dtype: int64
# 0

# %%
df_clean = pd.read_csv('/content/drive/MyDrive/datasetAndProgram/clean_renewable_energy_dataset.csv')
print(df_clean.head())
# Out:
#      Country  Year Energy Type  Production (GWh)  Installed Capacity (MW)  \
# 0        USA  2011       Solar      85404.690027              5549.794323
# 1  Australia  2008  Geothermal      22205.069382             43211.593798
# 2     Canada  2013     Biomass      94102.732038              6139.117212
# 3      Japan  2010     Biomass      88771.932910             40323.639260
# 4      China  2018       Solar      93288.408581             30755.403056
#
#    Investments (USD)  Population           GDP  Energy Consumption  \
# 0       5.604125e+09  1064007213  1.775278e+14       369654.644184
# 1       6.361886e+08  1033255852  6.435372e+13       771781.636293
# 2       6.158680e+09    14895124  1.567926e+14       342707.152899
# 3       8.526116e+09  1448827283  1.350464e+14       498839.574253
# 4       5.086237e+09  1499494307  8.677956e+13       819064.362785
#
#    Energy Exports  ...  Economic Freedom Index  Ease of Doing Business  \
# 0    93087.198199  ...               49.216800               57.678605
# 1     1752.536054  ...               79.990942                1.761579
# 2    65146.592498  ...               94.374040               77.657334
# 3    50257.591014  ...               65.143472               44.987734
# 4    63101.395562  ...               86.213626               62.535223
#
#    Innovation Index  Number of Research Institutions  \
# 0         76.803228                              851
# 1         48.697825                              590
# 2         67.334813                              101
# 3          4.544289                              327
# 4         10.287199                              985
#
#    Number of Renewable Energy Conferences  \
# 0                                      75
# 1                                      39
# 2                                       7
# 3                                       3
# 4                                      69
#
#    Number of Renewable Energy Publications  Energy Sector Workforce  \
# 0                                     6361                   511658
# 1                                     9752                   974948
# 2                                      311                   326318
# 3                                     7708                   506078
# 4                                     4919                   187964
#
#    Proportion of Energy from Renewables  \
# 0                             25.907895
# 1                             95.003547
# 2                             67.354539
# 3                             33.754104
# 4                             59.509228
#
#    Public-Private Partnerships in Energy  \
# 0                                      1
# 1                                      0
# 2                                      1
# 3                                      0
# 4                                      1
#
#    Regional Renewable Energy Cooperation
# 0                                      0
# 1                                      1
# 2                                      0
# 3                                      0
# 4                                      0
#
# [5 rows x 56 columns]

# %% [markdown]
# Descriptive Statistics

# %%
df_clean.describe()
# Out:
#               Year  Production (GWh)  Installed Capacity (MW)  \
# count  2500.000000       2500.000000              2500.000000
# mean   2011.437600      48743.195073             24882.910674
# std       6.895471      28340.915147             14463.459958
# min    2000.000000       1053.354158               114.531639
# 25%    2006.000000      24309.656479             12282.213159
# 50%    2011.000000      47367.117600             24689.162460
# 75%    2017.250000      73079.452832             37438.443570
# max    2023.000000      99937.503719             49997.387577
#
#        Investments (USD)    Population           GDP  Energy Consumption  \
# count       2.500000e+03  2.500000e+03  2.500000e+03         2500.000000
# mean        4.956155e+09  7.458927e+08  1.010745e+14       495701.245158
# std         2.894789e+09  4.373146e+08  5.782363e+13       291419.017957
# min         5.886994e+06  1.255357e+06  5.603965e+10         1264.851083
# 25%         2.473145e+09  3.720811e+08  5.049265e+13       237300.546551
# 50%         4.961772e+09  7.515190e+08  1.027006e+14       496118.165272
# 75%         7.418384e+09  1.118019e+09  1.519604e+14       753779.282813
# max         9.998292e+09  1.499494e+09  1.999223e+14       999618.512172
#
#        Energy Exports  Energy Imports  CO2 Emissions  ...  \
# count     2500.000000     2500.000000    2500.000000  ...
# mean     50143.392627    50800.373871  491218.412643  ...
# std      28833.333066    28740.851763  289783.733338  ...
# min       1036.618008     1057.783513    1124.768458  ...
# 25%      25146.745295    26347.461047  242894.720511  ...
# 50%      49706.656938    50698.800022  475721.007886  ...
# 75%      75567.191515    75807.642495  747649.446362  ...
# max      99952.509817    99912.213813  999816.500175  ...
#
#        Economic Freedom Index  Ease of Doing Business  Innovation Index  \
# count             2500.000000             2500.000000       2500.000000
# mean                50.736720               48.442085         50.280019
# std                 28.623766               28.798216         28.719483
# min                  0.104915                0.025281          0.025733
# 25%                 26.241437               23.519814         25.934406
# 50%                 50.850766               48.127673         51.398964
# 75%                 74.908485               73.324825         74.724073
# max                 99.970526               99.901347         99.998838
#
#        Number of Research Institutions  \
# count                      2500.000000
# mean                        496.660400
# std                         296.181011
# min                           0.000000
# 25%                         234.000000
# 50%                         493.000000
# 75%                         755.000000
# max                         999.000000
#
#        Number of Renewable Energy Conferences  \
# count                             2500.000000
# mean                                50.431200
# std                                 28.877168
# min                                  0.000000
# 25%                                 26.000000
# 50%                                 51.000000
# 75%                                 76.000000
# max                                 99.000000
#
#        Number of Renewable Energy Publications  Energy Sector Workforce  \
# count                               2500.00000              2500.000000
# mean                                4978.93360            502040.891200
# std                                 2881.93256            293084.636148
# min                                    3.00000               494.000000
# 25%                                 2532.00000            244438.000000
# 50%                                 4992.50000            499151.000000
# 75%                                 7465.00000            765088.000000
# max                                 9999.00000            999226.000000
#
#        Proportion of Energy from Renewables  \
# count                           2500.000000
# mean                              49.749110
# std                               28.924307
# min                                0.033829
# 25%                               23.968451
# 50%                               50.232069
# 75%                               74.354781
# max                               99.988355
#
#        Public-Private Partnerships in Energy  \
# count                            2500.000000
# mean                                0.512000
# std                                 0.499956
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 1.000000
# 75%                                 1.000000
# max                                 1.000000
#
#        Regional Renewable Energy Cooperation
# count                            2500.000000
# mean                                0.473600
# std                                 0.499402
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 1.000000
# max                                 1.000000
#
# [8 rows x 54 columns]

# %%
#India statistics
df_india = df[df['Country'] == 'India']
df_india = df_india[[
    'Year',
    'Energy Type',
    'Production (GWh)',
    'Installed Capacity (MW)',
    'Proportion of Energy from Renewables',
    'Solar Irradiance',
    'Wind Speed',
    'Hydro Potential',
    'Geothermal Potential',
    'Biomass Availability',
    'Average Annual Temperature',
    'Annual Rainfall',
    'Energy Storage Capacity',
    'Grid Integration Capability'
]]

df_india.describe()
# df_india.head(5)
# Out:
#               Year  Production (GWh)  Installed Capacity (MW)  \
# count   249.000000        249.000000               249.000000
# mean   2012.108434      49553.173445             26075.528555
# std       6.500022      29178.818512             14162.084433
# min    2000.000000       1053.354158              1017.167130
# 25%    2007.000000      23892.450225             13912.820126
# 50%    2012.000000      47012.861272             26668.435813
# 75%    2018.000000      75237.227333             39250.936469
# max    2023.000000      99696.606403             49938.844619
#
#        Proportion of Energy from Renewables  Solar Irradiance  Wind Speed  \
# count                            249.000000        249.000000  249.000000
# mean                              49.626270        196.696934    7.614406
# std                               29.462056         57.953344    4.274056
# min                                0.339346        100.946585    0.050978
# 25%                               25.827003        145.413011    4.088354
# 50%                               49.761887        195.024337    7.825026
# 75%                               75.452314        245.482325   11.406504
# max                               99.044414        299.510887   14.875122
#
#        Hydro Potential  Geothermal Potential  Biomass Availability  \
# count       249.000000            249.000000            249.000000
# mean         49.217748             53.400476             50.117418
# std          30.088528             30.759801             29.403623
# min           0.385271              0.352350              0.024802
# 25%          21.097557             25.100679             26.521972
# 50%          46.408801             55.624737             48.346120
# 75%          76.060154             81.991956             75.893183
# max          99.219877             99.652792             99.484877
#
#        Average Annual Temperature  Annual Rainfall  Energy Storage Capacity  \
# count                  249.000000       249.000000               249.000000
# mean                    14.982112      1611.320347               535.074833
# std                     14.429674       848.362793               274.859165
# min                     -9.546147       101.082742                 1.157294
# 25%                      2.639817       906.061267               313.440312
# 50%                     14.998512      1617.916570               555.037281
# 75%                     27.588169      2344.561628               764.082199
# max                     39.900547      2997.513760               999.317268
#
#        Grid Integration Capability
# count                   249.000000
# mean                      0.482885
# std                       0.286047
# min                       0.001835
# 25%                       0.247034
# 50%                       0.464206
# 75%                       0.725406
# max                       0.997448

# %%
mean = df_india.mean(numeric_only= True)
median = df_india.median(numeric_only=True)
std = df_india.std(numeric_only=True)
var = df_india.var(numeric_only = True)
print("Mean:\n", mean)
print("Median:\n", median)
print("Standard Deviation:\n", std)
print("Variance:\n", var)
# Out:
# Mean:
#  Year                                     2012.108434
# Production (GWh)                        49553.173445
# Installed Capacity (MW)                 26075.528555
# Proportion of Energy from Renewables       49.626270
# Solar Irradiance                          196.696934
# Wind Speed                                  7.614406
# Hydro Potential                            49.217748
# Geothermal Potential                       53.400476
# Biomass Availability                       50.117418
# Average Annual Temperature                 14.982112
# Annual Rainfall                          1611.320347
# Energy Storage Capacity                   535.074833
# Grid Integration Capability                 0.482885
# dtype: float64
# Median:
#  Year                                     2012.000000
# Production (GWh)                        47012.861272
# Installed Capacity (MW)                 26668.435813
# Proportion of Energy from Renewables       49.761887
# Solar Irradiance                          195.024337
# Wind Speed                                  7.825026
# Hydro Potential                            46.408801
# Geothermal Potential                       55.624737
# Biomass Availability                       48.346120
# Average Annual Temperature                 14.998512
# Annual Rainfall                          1617.916570
# Energy Storage Capacity                   555.037281
# Grid Integration Capability                 0.464206
# dtype: float64
# Standard Deviation:
#  Year                                        6.500022
# Production (GWh)                        29178.818512
# Installed Capacity (MW)                 14162.084433
# Proportion of Energy from Renewables       29.462056
# Solar Irradiance                           57.953344
# Wind Speed                                  4.274056
# Hydro Potential                            30.088528
# Geothermal Potential                       30.759801
# Biomass Availability                       29.403623
# Average Annual Temperature                 14.429674
# Annual Rainfall                           848.362793
# Energy Storage Capacity                   274.859165
# Grid Integration Capability                 0.286047
# dtype: float64
# Variance:
#  Year                                    4.225029e+01
# Production (GWh)                        8.514034e+08
# Installed Capacity (MW)                 2.005646e+08
# Proportion of Energy from Renewables    8.680128e+02
# Solar Irradiance                        3.358590e+03
# Wind Speed                              1.826756e+01
# Hydro Potential                         9.053195e+02
# Geothermal Potential                    9.461653e+02
# Biomass Availability                    8.645730e+02
# Average Annual Temperature              2.082155e+02
# Annual Rainfall                         7.197194e+05
# Energy Storage Capacity                 7.554756e+04
# Grid Integration Capability             8.182273e-02
# dtype: float64

# %%
# Visualization
plt.figure(figsize = (5, 5))
sns.histplot(x = df_india['Production (GWh)'])
plt.xlabel('Production (GWh)')
plt.ylabel('Frequency')
plt.title('Distribution of Production')
plt.show()

# %%
plt.figure(figsize = (5, 5))
sns.boxplot(x = df_india['Production (GWh)'])
plt.xlabel('Production (GWh)')
plt.ylabel('Frequency')
plt.title('Distribution of Production')
plt.show()

print(df_india['Production (GWh)'].describe())
# Out:
# count      249.000000
# mean     49553.173445
# std      29178.818512
# min       1053.354158
# 25%      23892.450225
# 50%      47012.861272
# 75%      75237.227333
# max      99696.606403
# Name: Production (GWh), dtype: float64

# %%
plt.figure(figsize = (20, 5))
x = df_india['Year']
y = df_india['Production (GWh)']
plt.bar(x, y, color = 'red', edgecolor = 'black')
plt.ylabel('Production (GWh)')
plt.xlabel('Year')
plt.title('Year wise Production of India')
plt.show()

# %%
plt.figure(figsize = (20, 10))
cor = df_india.corr(numeric_only = True)
# print(cor)
sns.heatmap(cor, annot = True, cmap = plt.cm.Reds)
plt.plot()
plt.show()

# %% [markdown]
# Inferential Statistics

# %% [markdown]
# One-Sample t-Test
# Hypothesis
# Determine whether the mean production of a particular energy type differs from a benchmark value.
# Example:
# H0 : Mean Solar production = 5000 GWh
# H1 : Mean Solar production ≠ 5000 GWh

# %%
from scipy import stats

solar = df_india[df_india['Energy Type'] == 'Solar']['Production (GWh)']
tstat, pvalue = stats.ttest_1samp(solar, popmean= 5000)
print('t-statistic:', tstat)
print('p-value:', pvalue)

#Decision
# t-statistic: 9.969303418700171
# p-value: 4.988865593285651e-12
# Since p < 0.05, reject H0.
# Conclusion: The average production is significantly different from the benchmark value used in the test.
# Out:
# t-statistic: 9.969303418700171
# p-value: 4.988865593285651e-12

# %% [markdown]
# Independent Two-Sample t-Test
# Hypothesis
# Compare mean production between two energy types.
# Example:H0 : Mean Solar production = Mean Wind production
# H1 : Means are different

# %%
from scipy import stats

solar = df_india[df_india['Energy Type'] == 'Solar']['Production (GWh)']
wind = df_india[df_india['Energy Type'] == 'Wind']['Production (GWh)']
tstat, pvalue = stats.ttest_ind(solar, wind, equal_var= False)
print('t-statistic:', tstat)
print('p-value:', pvalue)

# t-statistic: 0.011645532435746335
# p-value: 0.9907390496073831
# The p-value (0.9907) is much larger than the common significance level of 0.05.
# Since:
                          # p=0.9907>0.05 -- fail to reject the null hypothesis.
# Conclusion
# There is no statistically significant difference between the mean production values of the two energy types being compared.
# Out:
# t-statistic: 0.011645532435746335
# p-value: 0.9907390496073831

# %% [markdown]
# One-Way ANOVA
#
# Hypothesis
#
# Test whether average production differs among all energy types.
#
# H0 : All energy types have the same mean production
#
# H1 : At least one mean differs

# %%
from scipy.stats import f_oneway

biomass = df_india[df_india['Energy Type']=='Biomass']['Production (GWh)']
geo = df_india[df_india['Energy Type']=='Geothermal']['Production (GWh)']
hydro = df_india[df_india['Energy Type']=='Hydro']['Production (GWh)']
solar = df_india[df_india['Energy Type']=='Solar']['Production (GWh)']
wind = df_india[df_india['Energy Type']=='Wind']['Production (GWh)']
fstat, pvalue = f_oneway(biomass, geo, hydro, solar, wind)
print('F-statistic:', fstat)
print('p-value:', pvalue)

# The p-value is: 0.7235650798228652
# 0.7235650798228652 > 0.05
# the result is not statistically significant.

# Decision
# Fail to reject the null hypothesis (H0).

# Conclusion
# There is no statistically significant evidence that the average production differs among the five energy types.
# Out:
# F-statistic: 0.5166490136995041
# p-value: 0.7235650798228652

# %% [markdown]
# Two-Way ANOVA
# Useful because your data has:
# • Energy Type
# • Year
# Hypothesis
# Factor 1: Energy Type affects production
# Factor 2: Year affects production
# Interaction: Energy Type x Year affects production

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols(
    'Q("Production (GWh)") ~ C(Q("Energy Type")) + C(Year) + C(Q("Energy Type")):C(Year)',
    data=df_india
).fit()

anova_table = sm.stats.anova_lm(model, typ=2)

print(anova_table)

#  Source              Fvalue  pvalue (PR(>F))  Interpretation

#  Energy Type         0.373    0.772             Not significant
#  Year                1.478    0.132             Not significant
#  Energy Type x Year  0.858    0.775             Not significant


# Using the common significance level of alpha = 0.05:

# Energy Type: p = 0.772 > 0.05: No statistically significant difference among energy types.

# Year: p = 0.132 > 0.05: No statistically significant change across years.

# Interaction: p = 0.775 > 0.05: The effect of energy type does not significantly depend on year.

# Conclusion
# The ANOVA provides no evidence that the production differs significantly by energy type, by year, or by the combination of energy type and year.
# Out:
#                                    sum_sq     df         F    PR(>F)
# C(Q("Energy Type"))          1.352403e+09    4.0  0.373271  0.772407
# C(Year)                      3.080081e+10   23.0  1.478469  0.132027
# C(Q("Energy Type")):C(Year)  7.153477e+10   92.0  0.858435  0.775021
# Residual                     1.313379e+11  145.0       NaN       NaN
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 23, but rank is 13
#   warnings.warn('covariance of constraints does not have full '
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 92, but rank is 82
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# Chi-Square Test of Independence
#
# Chi-square requires categorical variables.
#
# Since Production is continuous, first convert it into categories.
#
# Hypothesis
#
# H0 : Energy Type and Production Level are independent
#
# H1 : They are associated

# %%
df_india['Production Category'] = pd.cut(
    df_india['Production (GWh)'],
    bins = 3,
    labels = ["low", "medium", "high"])

df_india['Production Category']
# Out:
# 5         high
# 16        high
# 21         low
# 30        high
# 58        high
#          ...
# 2407    medium
# 2441    medium
# 2453      high
# 2466      high
# 2497      high
# Name: Production Category, Length: 249, dtype: category
# Categories (3, object): ['low' < 'medium' < 'high']

# %%
from scipy.stats import chi2_contingency

Ctable = pd.crosstab(df_india['Energy Type'], df_india['Production Category'])

chi2, pvalue, dof, expected = chi2_contingency(Ctable)

print('Chi-square statistic:', chi2)

print('p-value:', pvalue)


# Decision

# Using a significance level of alpha = 0.05:

# p-value = 0.9187 > 0.05

# Therefore, fail to reject H0.

# Conclusion

# There is no statistically significant evidence of an association between Energy Type and Production Level.
# Out:
# Chi-square statistic: 3.235208869993634
# p-value: 0.918741491862118

# %% [markdown]
# F-Statistic for Variance Comparison
#
# Compare variability between two energy types.
#
# H0 : Variances are equal

# %%
from scipy.stats import f

solar = df_india[df_india['Energy Type'] == 'Solar']['Production (GWh)']
wind = df_india[df_india['Energy Type'] == 'Wind']['Production (GWh)']
var1 = np.var(solar, ddof = 1)
var2 = np.var(wind, ddof = 1)
fstat = var1 / var2
dfsolar = len(solar) - 1
dfwind = len(wind) - 1
pvalue = 2 * min(f.cdf(fstat, dfsolar, dfwind), 1 - f.cdf(fstat, dfsolar, dfwind))

print('F-statistic:', fstat)

print('p-value:', pvalue)

# Decision

# Using alpha = 0.05:

# p-value = 0.9722 > 0.05

# Therefore, fail to reject H0.

# Conclusion

# There is no statistically significant evidence that the variances differ between the two energy types. ]

# The production levels for the two energy types exhibit similar variability.
# Out:
# F-statistic: 0.9813165938664655
# p-value: 0.9722070739741067

# %% [markdown]
# Trend Analysis Over Years (Regression)
#
# Hypothesis
#
# H0 : Production does not change with Year
#
# H1 : Production changes with Year

# %%
from scipy.stats import linregress

solar = df_india[df_india['Energy Type'] == 'Solar']
x = solar['Year']
y = solar['Production (GWh)']
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
print('Slope:', slope)
print('p-value:', pvalue)
print('rvalue', rvalue**2)
print('error', stderr)


# Results
# Slope = 1123.46
# p-value = 0.1693
# Correlation coefficient (r) = 0.0518
# Standard error of slope = 800.89

# Decision

# Using alpha = 0.05:

# p-value = 0.1693 > 0.05
# Therefore, fail to reject H0.

# Interpretation
# Though the estimated slope is positive (1123.46), suggesting production increases by about 1,123 units per year on average,
# this trend is not statistically significant.

# The correlation coefficient:
# r = 0.0518 : indicates an extremely weak positive relationship between Year and Production.

# The coefficient of determination is:
# rsquare =(0.0518)^2 = 0.0027

# This means that only about 0.27% of the variation in production is explained by year, which is negligible.

# Conclusion
# There is insufficient evidence to conclude that production levels have changed significantly over time.
# The observed increase in production is small relative to the variability in the data and may be due to random variation.
# Out:
# Slope: 1123.4557679953195
# p-value: 0.16925447799036047
# rvalue 0.05182644107594913
# error 800.8901541731302

# %% [markdown]
# Confidence Interval for Mean Production
#
# Example: Solar
#
# 95% confidence interval for average production.

# %%
from scipy.stats import t

solar = df_india[df_india['Energy Type']=='Solar']['Production (GWh)']

n = len(solar)
mean = np.mean(solar)
std = np.std(solar, ddof=1)

ci = t.interval(
confidence=0.95,
df=n-1,
loc=mean,
scale=std/np.sqrt(n)
)
print("Mean:", mean)
print("95% CI:", ci)
# Out:
# Mean: 52553.2855258488
# 95% CI: (np.float64(42888.40677975595), np.float64(62218.16427194165))
